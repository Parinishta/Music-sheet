# %%
from tensorflow.keras.optimizers import Adam
import numpy as np
import cv2
import os
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.layers import Dense, Dropout, Activation, Flatten, Softmax
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.layers import Conv2D , MaxPooling2D
import pickle

##################################
path= 'Notes'
testRatio=0.2
valRatio=0.2
imageDimensions=(32,32,3)

batchSizeVal= 50
epochsVal= 30
stepsPerEpoch = 20

####################################
images =[]
count=0
classNo =[]
List= os.listdir(path)
print("Total no of clases detected",len(List))
noOfClasses = len(List)
print("Importing classes....")
for x in range (0,noOfClasses):
    PicList = os.listdir(path+"/"+str((x)))

    for y in PicList:
         curImg = cv2.imread(path+"/"+str(x)+"/"+y)
         curImg =cv2.resize(curImg,(32,32))
         images.append(curImg)
         classNo.append(count)
    print(count,end= " ")
    count +=1
print(" ")

images = np.array(images)
classNo = np.array(classNo)
print(images.shape)
## Spliting the data
x_train, x_test,y_train,y_test = train_test_split(images,classNo,test_size=0.2)
x_train,x_validation,y_train,y_validation=train_test_split(x_train,y_train,test_size=valRatio)
print(x_train.shape)
print(x_test.shape)
print(x_validation.shape)


numOfSamples= []
for x in range(0,noOfClasses):
    ##print(len(np.where(y_train==0)[0]))
    numOfSamples.append(len(np.where(y_train==x)[0]))
print(numOfSamples)

plt.figure(figsize=(10,5))
plt.bar(range(0,noOfClasses),numOfSamples)
plt.title("No of Images for each Class")
plt.xlabel("Class ID")
plt.ylabel("Number of Images")
plt.show()

def preProcessing(img):
        img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        img = cv2.equalizeHist(img)
        img = img/255
        return img

#img = preProcessing(x_train[30])
#img=cv2.resize(img,(300,300))
#cv2.imshow("PreProcessed",img)
#cv2.waitKey(0)

x_train=np.array(list(map(preProcessing,x_train)))
x_test=np.array(list(map(preProcessing,x_test)))
x_validation=np.array(list(map(preProcessing,x_validation)))

x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],x_train.shape[2],1)
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],x_test.shape[2],1)
x_validation = x_validation.reshape(x_validation.shape[0],x_validation.shape[1],x_validation.shape[2],1)

dataGen = ImageDataGenerator(width_shift_range=0.1,
                             height_shift_range=0.1,
                             zoom_range=0.2,
                             shear_range=0.1,
                             rotation_range=10)

dataGen.fit(x_train)

y_train=to_categorical(y_train,noOfClasses)
y_test=to_categorical(y_test,noOfClasses)
y_validation=to_categorical(y_validation,noOfClasses)

def myModel():
    noOfFilters= 60
    sizeOfFilter1=(5,5)
    sizeOfFilter2= (3,3)
    sizeOfPool= (2,2)
    noOfNode = 500

    model = Sequential()
    model.add((Conv2D(noOfFilters,sizeOfFilter1,input_shape=(imageDimensions[0],imageDimensions[1],1), activation='relu')))
    model.add((Conv2D(noOfFilters, sizeOfFilter1, activation='relu')))
    model.add(MaxPooling2D(pool_size=sizeOfPool))
    model.add((Conv2D(noOfFilters//2, sizeOfFilter2, activation='relu')))
    model.add((Conv2D(noOfFilters//2, sizeOfFilter2, activation='relu')))
    model.add(MaxPooling2D(pool_size=sizeOfPool))
    model.add(Dropout(0.5))

    model.add(Flatten())
    model.add(Dense(noOfNode,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(noOfClasses,activation='softmax'))
    model.compile(Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
    return model

model = myModel()
print(model.summary())

history = model.fit(dataGen.flow(x_train,y_train,batch_size=batchSizeVal),steps_per_epoch=stepsPerEpoch,
                    epochs=epochsVal,validation_data=(x_validation,y_validation),
                    shuffle=1)

"""
new_img = cv2.imread()
pred = model.predict(new_img)

"""

# print(history)
plt.figure(1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training','validation'])
plt.title('Loss')
plt.xlabel('epoch')
plt.figure(2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training','validation'])
plt.title('Accuracy')
plt.xlabel('epoch')
plt.show()
score = model.evaluate(x_test,y_test,verbose=0)
print('Test Score = ',score[0])
print('Test Accuracy =', score[1])

pickle_out = open("model_trained.pkl","wb")
pickle.dump(model,pickle_out)
pickle_out.close()
# Out:
# Total no of clases detected 5
# Importing classes....
# 0 1 2 3 4
# (5000, 32, 32, 3)
# (3200, 32, 32, 3)
# (1000, 32, 32, 3)
# (800, 32, 32, 3)
# [646, 652, 638, 653, 611]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 60)        1560
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 60)        90060
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 60)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 30)        16230
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 30)          8130
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 30)         0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 30)          0
#
#  flatten (Flatten)           (None, 480)               0
#
#  dense (Dense)               (None, 500)               240500
#
#  dropout_1 (Dropout)         (None, 500)               0
#
#  dense_1 (Dense)             (None, 5)                 2505
#
# =================================================================
# Total params: 358,985
# Trainable params: 358,985
# Non-trainable params: 0
# _________________________________________________________________
# c:\Users\Sree\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# None
# Epoch 1/30
# 20/20 [==============================] - 9s 94ms/step - loss: 1.6158 - accuracy: 0.2170 - val_loss: 1.5861 - val_accuracy: 0.4013
# Epoch 2/30
# 20/20 [==============================] - 1s 55ms/step - loss: 1.5152 - accuracy: 0.3280 - val_loss: 1.1836 - val_accuracy: 0.5188
# Epoch 3/30
# 20/20 [==============================] - 1s 65ms/step - loss: 1.2822 - accuracy: 0.4370 - val_loss: 0.9547 - val_accuracy: 0.5638
# Epoch 4/30
# 20/20 [==============================] - 1s 35ms/step - loss: 1.1420 - accuracy: 0.4870 - val_loss: 0.7918 - val_accuracy: 0.6300
# Epoch 5/30
# 20/20 [==============================] - 1s 34ms/step - loss: 1.0675 - accuracy: 0.5280 - val_loss: 0.6807 - val_accuracy: 0.6875
# Epoch 6/30
# 20/20 [==============================] - 1s 32ms/step - loss: 0.9610 - accuracy: 0.5560 - val_loss: 0.6403 - val_accuracy: 0.7088
# Epoch 7/30
# 20/20 [==============================] - 1s 44ms/step - loss: 0.9075 - accuracy: 0.5910 - val_loss: 0.6506 - val_accuracy: 0.6650
# Epoch 8/30
# 20/20 [==============================] - 1s 49ms/step - loss: 0.9175 - accuracy: 0.5500 - val_loss: 0.6193 - val_accuracy: 0.7212
# Epoch 9/30
# 20/20 [==============================] - 1s 42ms/step - loss: 0.7582 - accuracy: 0.6440 - val_loss: 0.5469 - val_accuracy: 0.7487
# Epoch 10/30
# 20/20 [==============================] - 1s 39ms/step - loss: 0.7446 - accuracy: 0.6390 - val_loss: 0.4710 - val_accuracy: 0.7750
# Epoch 11/30
# 20/20 [==============================] - 1s 40ms/step - loss: 0.6933 - accuracy: 0.6750 - val_loss: 0.4531 - val_accuracy: 0.7862
# Epoch 12/30
# 20/20 [==============================] - 1s 40ms/step - loss: 0.7054 - accuracy: 0.6710 - val_loss: 0.4395 - val_accuracy: 0.7775
# Epoch 13/30
# 20/20 [==============================] - 1s 40ms/step - loss: 0.6786 - accuracy: 0.7020 - val_loss: 0.4294 - val_accuracy: 0.7987
# Epoch 14/30
# 20/20 [==============================] - 1s 43ms/step - loss: 0.6155 - accuracy: 0.7000 - val_loss: 0.3837 - val_accuracy: 0.8075
# Epoch 15/30
# 20/20 [==============================] - 1s 49ms/step - loss: 0.5994 - accuracy: 0.7350 - val_loss: 0.3786 - val_accuracy: 0.8325
# Epoch 16/30
# 20/20 [==============================] - 1s 48ms/step - loss: 0.5805 - accuracy: 0.7250 - val_loss: 0.3728 - val_accuracy: 0.8462
# Epoch 17/30
# 20/20 [==============================] - 1s 50ms/step - loss: 0.5702 - accuracy: 0.7400 - val_loss: 0.3408 - val_accuracy: 0.8475
# Epoch 18/30
# 20/20 [==============================] - 1s 55ms/step - loss: 0.5708 - accuracy: 0.7390 - val_loss: 0.3976 - val_accuracy: 0.8000
# Epoch 19/30
# 20/20 [==============================] - 1s 48ms/step - loss: 0.5512 - accuracy: 0.7360 - val_loss: 0.3513 - val_accuracy: 0.8350
# Epoch 20/30
# 20/20 [==============================] - 1s 49ms/step - loss: 0.5037 - accuracy: 0.7740 - val_loss: 0.3227 - val_accuracy: 0.8388
# Epoch 21/30
# 20/20 [==============================] - 1s 43ms/step - loss: 0.5104 - accuracy: 0.7840 - val_loss: 0.3263 - val_accuracy: 0.8300
# Epoch 22/30
# 20/20 [==============================] - 1s 43ms/step - loss: 0.4985 - accuracy: 0.7740 - val_loss: 0.3745 - val_accuracy: 0.8275
# Epoch 23/30
# 20/20 [==============================] - 1s 44ms/step - loss: 0.5044 - accuracy: 0.7680 - val_loss: 0.3134 - val_accuracy: 0.8712
# Epoch 24/30
# 20/20 [==============================] - 1s 40ms/step - loss: 0.4616 - accuracy: 0.8030 - val_loss: 0.3148 - val_accuracy: 0.8550
# Epoch 25/30
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5505 - accuracy: 0.7690 - val_loss: 0.3373 - val_accuracy: 0.8600
# Epoch 26/30
# 20/20 [==============================] - 1s 34ms/step - loss: 0.4697 - accuracy: 0.7900 - val_loss: 0.2939 - val_accuracy: 0.8650
# Epoch 27/30
# 20/20 [==============================] - 1s 35ms/step - loss: 0.4500 - accuracy: 0.8010 - val_loss: 0.2868 - val_accuracy: 0.8875
# Epoch 28/30
# 20/20 [==============================] - 1s 37ms/step - loss: 0.4452 - accuracy: 0.7900 - val_loss: 0.2821 - val_accuracy: 0.8750
# Epoch 29/30
# 20/20 [==============================] - 1s 39ms/step - loss: 0.4421 - accuracy: 0.8140 - val_loss: 0.2911 - val_accuracy: 0.8562
# Epoch 30/30
# 20/20 [==============================] - 1s 39ms/step - loss: 0.3769 - accuracy: 0.8390 - val_loss: 0.2612 - val_accuracy: 0.8725
# Test Score =  0.2821388840675354
# Test Accuracy = 0.8619999885559082
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://a89c1524-ef9a-4a7b-85ed-2a4e503e0540/assets
# INFO:tensorflow:Assets written to: ram://a89c1524-ef9a-4a7b-85ed-2a4e503e0540/assets

# %%
import numpy as np
import cv2
import pickle

##########################################
width = 640
height = 480
threshold = 0.85
##########################################
cap = cv2.VideoCapture(0)
cap.set(3,width)
cap.set(4,height)

pickle_in = open("model_trained.pkl","rb+")
# model = pickle.loads(pickle_in)

def preProcessing(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.equalizeHist(img)
    img = img / 255
    return img

while True:
    success, imgOriginal = cap.read()
    imgOriginal = cv2.imread("C:\\Users\\Sree\\PycharmProjects\\serious\\Notes\\1\\h1.jpg")
    img = np.asarray(imgOriginal)
    img = cv2.resize(img,(32,32))
    img = preProcessing(img)
    cv2.imshow("Processed Image",img)
    img = img.reshape(1,32,32,1)

    #Predict
    # classIndex = int(model.predict_classes(img))
    #print(classIndex)
    predictions = model.predict(img)[0]
    print(predictions)
    probVal= np.amax(predictions)
    # print(classIndex,probVal)

    # if probVal> threshold:
      #     cv2.putText(imgOriginal,str(classIndex) +"  "+str(probVal),(50,50),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),1)
    cv2.imshow("Original Image",imgOriginal)

    if cv2.waitKey(1) &0xFF == ord('q'):
        break

cv2.destroyAllWindows()
cap.release()
# Out:
# 1/1 [==============================] - 0s 49ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 42ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 47ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 38ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 40ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 35ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 35ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 34ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 27ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 29ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 32ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 27ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 28ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 29ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 26ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 28ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 28ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 26ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 26ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 27ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 27ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 37ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 39ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 36ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 34ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 37ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 35ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 38ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 39ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 35ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 38ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 38ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 35ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 24ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 34ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 39ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 37ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 32ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 38ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 34ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 27ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 28ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 29ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 30ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 26ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 24ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 24ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 25ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 23ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 23ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 28ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 25ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 28ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 31ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 29ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 28ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 56ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 27ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 32ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 28ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 27ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 26ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 34ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 32ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 29ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 32ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 32ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 31ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 32ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 36ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 23ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 31ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 34ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 33ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 29ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 34ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 31ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 32ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 32ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 34ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 30ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 28ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 28ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 27ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]
# 1/1 [==============================] - 0s 26ms/step
# [6.0262991e-08 9.9981719e-01 1.8263786e-04 1.3595058e-08 1.4652213e-07]

# %%
cv2.destroyAllWindows()
cap.release()

# %%
def sliding_window(image, stepSize):
	imgarr=[]
	# xarr = []
	# yarr = []

	Eline[]=[[115,][212][320][426]]
	Gline[]=[[109][206][314][420]]
	#F if condition stating that it touches both.
	Cline[]=[[120][216][325][432]]
	Dline[]=[[115 &&119][212&&216][320&&324][426&&430]]
	Fline[]=[[109 && 115][206&&212][320&&314][426&&420]]
	#Aline[]=[[]]
	#Bline[]=[[]]
	##################################################
Cl2[]=[[115&&119],[216],[314],[430]]
cl1[]=[[115],[115 &&119],[109],[109 && 115],[212][320][426][206][314][420][120][216][325][432][212&&216][320&&324][426&&430][206&&212][320&&314][426&&420]]

class0[]=[]
class1[]=[]
class2[]=[]
class3[]=[]
class4[]=[]
	# slide a window across the image
	for y in range(0, image.shape[0] - stepSize - 1):
		for x in range(0, image.shape[1] - stepSize - 1):
			# yield the current window
			img=image[y:y+stepSize,x:x+stepSize]
			# Prediction of the class here
			 print(classIndex,probVal)
 		    if probVal> threshold:
      			cv2.putText(imgOriginal,str(classIndex) +"  "+str(probVal),(50,50),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),1)
# Append the coords in xarr and yarr


for 
			if probVal in predictions[0]
			class0.append(x,y)
			if probVal in predictions[1]
			class1.append(x,y)
			if probVal in predictions[2]
			class2.append(x,y)
			if probVal in predictions[3]
			class3.append(x,y)
			if probVal in predictions[4]
			class4.append(x,y)
		# Return the xarr and yarr
			imgarr.append(img)
	return imgarr
# Out:
#   File <tokenize>:30
#     if probVal> threshold:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
testimage=cv2.imread("download.png")
imarr=sliding_window(testimage,stepSize=32)
count=0
for i in imarr:
    img = np.asarray(i)
    img = cv2.resize(img,(32,32))
    img = preProcessing(img)
    cv2.imshow("Processed Image",img)
    img = img.reshape(1,32,32,1)

    #Predict
    # classIndex = int(model.predict_classes(img))
    #print(classIndex)
    predictions = model.predict(img)[0]
    print(predictions)
    probVal= np.amax(predictions)#insert max function
    count+=1
    #identify index of max
# Out:
# 1/1 [==============================] - 0s 25ms/step
# [2.0199411e-06 9.9980623e-01 1.8807911e-04 4.0743674e-07 3.3409765e-06]
# 1/1 [==============================] - 0s 30ms/step
# [1.5932047e-06 9.9990451e-01 8.8551482e-05 3.5571313e-07 4.9867840e-06]
# 1/1 [==============================] - 0s 25ms/step
# [1.7190613e-06 9.9994183e-01 5.0741994e-05 3.2299280e-07 5.4997367e-06]
# 1/1 [==============================] - 0s 35ms/step
# [2.1029259e-06 9.9995124e-01 3.2076605e-05 3.5475369e-07 1.4164751e-05]
# 1/1 [==============================] - 0s 34ms/step
# [1.9531939e-05 9.9981648e-01 7.2632400e-05 2.9640705e-06 8.8453970e-05]
# 1/1 [==============================] - 0s 36ms/step
# [5.7961366e-05 9.9957436e-01 1.7222934e-04 8.6838427e-06 1.8686066e-04]
# 1/1 [==============================] - 0s 36ms/step
# [2.0557982e-04 9.9909282e-01 3.9234830e-04 2.9960493e-05 2.7926662e-04]
# 1/1 [==============================] - 0s 22ms/step
# [8.8182121e-04 9.9696666e-01 9.2358340e-04 2.0826457e-04 1.0195918e-03]
# 1/1 [==============================] - 0s 29ms/step
# [0.0048769  0.98690027 0.00258968 0.00170494 0.00392831]
# 1/1 [==============================] - 0s 25ms/step
# [0.01274056 0.9667087  0.0064543  0.00610447 0.00799191]
# 1/1 [==============================] - 0s 28ms/step
# [0.02838227 0.9333712  0.01106869 0.01360933 0.01356853]
# 1/1 [==============================] - 0s 32ms/step
# [0.05918574 0.8574907  0.01704446 0.02790041 0.03837857]
# 1/1 [==============================] - 0s 28ms/step
# [0.06141774 0.8411414  0.01785013 0.02687004 0.05272077]
# 1/1 [==============================] - 0s 29ms/step
# [0.07892089 0.80164933 0.02535908 0.03459804 0.05947254]
# 1/1 [==============================] - 0s 34ms/step
# [0.04291493 0.8542204  0.02046453 0.01866424 0.0637359 ]
# 1/1 [==============================] - 0s 30ms/step
# [0.04155226 0.84706855 0.02815712 0.02307658 0.0601455 ]
# 1/1 [==============================] - 0s 27ms/step
# [0.02306267 0.86083215 0.01753999 0.01495537 0.08360985]
# 1/1 [==============================] - 0s 27ms/step
# [0.0287468  0.81508714 0.02395998 0.02228566 0.10992034]
# 1/1 [==============================] - 0s 25ms/step
# [0.02768492 0.7678084  0.02356988 0.02645467 0.15448211]
# 1/1 [==============================] - 0s 30ms/step
# [0.02620011 0.75521076 0.02710092 0.02737898 0.16410922]
# 1/1 [==============================] - 0s 29ms/step
# [0.02646133 0.75088495 0.03220728 0.0297228  0.16072363]
# 1/1 [==============================] - 0s 25ms/step
# [0.03197915 0.7162591  0.04665082 0.03496284 0.1701481 ]
# 1/1 [==============================] - 0s 35ms/step
# [0.03148696 0.6918886  0.04996389 0.04102712 0.18563339]
# 1/1 [==============================] - 0s 36ms/step
# [0.04207381 0.6650553  0.06611539 0.04923186 0.17752363]
# 1/1 [==============================] - 0s 37ms/step
# [0.08444986 0.53723377 0.14831533 0.08236995 0.14763102]
# 1/1 [==============================] - 0s 35ms/step
# [0.1219437  0.43791097 0.22272769 0.10099699 0.11642065]
# 1/1 [==============================] - 0s 32ms/step
# [0.15613322 0.33235905 0.2928167  0.12059277 0.09809826]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Sree\PycharmProjects\serious\musi.ipynb Cell 5 in <cell line: 4>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Sree/PycharmProjects/serious/musi.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> img = img.reshape(1,32,32,1)
#      <a href='vscode-notebook-cell:/c%3A/Users/Sree/PycharmProjects/serious/musi.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> #Predict
#      <a href='vscode-notebook-cell:/c%3A/Users/Sree/PycharmProjects/serious/musi.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> # classIndex = int(model.predict_classes(img))
#      <a href='vscode-notebook-cell:/c%3A/Users/Sree/PycharmProjects/serious/musi.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a> #print(classIndex)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Sree/PycharmProjects/serious/musi.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a> predictions = model.predict(img)[0]
#      <a href='vscode-notebook-cell:/c%3A/Users/Sree/PycharmProjects/serious/musi.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a> print(predictions)
#      <a href='vscode-notebook-cell:/c%3A/Users/Sree/PycharmProjects/serious/musi.ipynb#W4sZmlsZQ%3D%3D?line=16'>17</a> probVal= np.amax(predictions)
#
# File c:\Users\Sree\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Sree\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:2002, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1995   except ValueError:
#    1996     warnings.warn(
#    1997         'Using Model.predict with MultiWorkerMirroredStrategy or '
#    1998         'TPUStrategy and AutoShardPolicy.FILE might lead to out-of-order '
#    1999         'result. Consider setting it to AutoShardPolicy.DATA.',
#    2000         stacklevel=2)
# -> 2002 data_handler = data_adapter.get_data_handler(
#    2003     x=x,
#    2004     batch_size=batch_size,
#    2005     steps_per_epoch=steps,
#    2006     initial_epoch=0,
#    2007     epochs=1,
#    2008     max_queue_size=max_queue_size,
#    2009     workers=workers,
#    2010     use_multiprocessing=use_multiprocessing,
#    2011     model=self,
#    2012     steps_per_execution=self._steps_per_execution)
#    2014 # Container that configures and calls `tf.keras.Callback`s.
#    2015 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\Sree\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:1401, in get_data_handler(*args, **kwargs)
#    1399 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1400   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1401 return DataHandler(*args, **kwargs)
#
# File c:\Users\Sree\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:1151, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1148   self._steps_per_execution = steps_per_execution
#    1150 adapter_cls = select_data_adapter(x, y)
# -> 1151 self._adapter = adapter_cls(
#    1152     x,
#    1153     y,
#    1154     batch_size=batch_size,
#    1155     steps=steps_per_epoch,
#    1156     epochs=epochs - initial_epoch,
#    1157     sample_weights=sample_weight,
#    1158     shuffle=shuffle,
#    1159     max_queue_size=max_queue_size,
#    1160     workers=workers,
#    1161     use_multiprocessing=use_multiprocessing,
#    1162     distribution_strategy=tf.distribute.get_strategy(),
#    1163     model=model)
#    1165 strategy = tf.distribute.get_strategy()
#    1167 self._current_step = 0
#
# File c:\Users\Sree\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:275, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     263 self._shuffle = shuffle
#     264 # Vectorized version of shuffle.
#     265 # This is a performance improvement over using `from_tensor_slices`.
#     266 # The indices of the data are shuffled and batched, and these indices
#    (...)
#     272 # 4. optimized permutation batching
#     273 # 5. disabled static optimizations
# --> 275 indices_dataset = tf.data.Dataset.range(1)
#     276 if shuffle != "batch":
#     277   indices_dataset = indices_dataset.repeat(epochs)
#
# File c:\Users\Sree\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:1211, in DatasetV2.range(*args, **kwargs)
#    1175 @staticmethod
#    1176 def range(*args, **kwargs):
#    1177   """Creates a `Dataset` of a step-separated range of values.
#    1178
#    1179   >>> list(Dataset.range(5).as_numpy_iterator())
#    (...)
#    1209     ValueError: if len(args) == 0.
#    1210   """
# -> 1211   return RangeDataset(*args, **kwargs)
#
# File c:\Users\Sree\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4777, in RangeDataset.__init__(self, *args, **kwargs)
#    4775 self._parse_args(*args, **kwargs)
#    4776 self._structure = tensor_spec.TensorSpec([], self._output_type)
# -> 4777 variant_tensor = gen_dataset_ops.range_dataset(
#    4778     start=self._start,
#    4779     stop=self._stop,
#    4780     step=self._step,
#    4781     **self._common_args)
#    4782 super(RangeDataset, self).__init__(variant_tensor)
#
# File c:\Users\Sree\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:6285, in range_dataset(start, stop, step, output_types, output_shapes, metadata, name)
#    6283 if tld.is_eager:
#    6284   try:
# -> 6285     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6286       _ctx, "RangeDataset", name, start, stop, step, "output_types",
#    6287       output_types, "output_shapes", output_shapes, "metadata", metadata)
#    6288     return _result
#    6289   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
"""
You'll get the class names and the corresponding y coords of every symbol.
Compare those y coords of the symbol to the y coords of the horizontal lines to get which line the symbol is touching.

You have which symbol (count) and where is the symbol (which key).
"""

# %%
################################################################################################
line_y_coords = [[94,99,105,109,115],[192,196,202,206,212],[299,304,309,315,320],[406,410,416,420,426]]
for a in range(0, 
    if note in line_y_coords 
    if note in Cline 
        cv2.puttext("C ")
    elif note in Dline 
        cv2.puttext("D ")
    elif note in Eline 
        cv2.puttext("E ")    
    elif note in Fline 
        cv2.puttext("F ")
   
    print(max)
